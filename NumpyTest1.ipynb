# %% [markdown]
# <a href="https://colab.research.google.com/github/twsteen/Numpy/blob/main/NumpyTest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr = np.array([10,20,30])
print (arr)
# Out:
# [10 20 30]

# %% [markdown]
# # Numpy

# %%
hello = 0

# %%
qaz = hello
print (qaz)
# Out:
# 0

# %%
arr.shape
arr = arr * 3
print (arr)
# Out:
# [30 60 90]

# %% [markdown]
# #Sinus

# %%
import numpy as np
import matplotlib.pyplot as plot

fs = 44100
t = 1

frequency = 20
samples = np.arange(t*fs)/fs

amplitude = np.sin(2*np.pi*frequency*samples)
plot.plot(samples, amplitude)
# Out:
# [    0     1     2 ... 44097 44098 44099]
